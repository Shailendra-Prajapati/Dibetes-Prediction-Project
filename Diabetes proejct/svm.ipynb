# %%
# Importing the libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# %%
# Importing the dataset
dataset = pd.read_csv('diabetes.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 8].values

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, 
                                                    random_state = 42)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

#svm with grid search
svm = SVC(random_state = 42)
parameters = {'kernel':('linear', 'rbf'), 'C':(1,0.25,0.5,0.75),
              'gamma': (1,2,3,'auto'),'decision_function_shape':('ovo','ovr'),
              'shrinking':(True,False)}

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    svm = GridSearchCV(SVC(), parameters, cv=5,
                       scoring='%s_macro' % score)
    svm.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(svm.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = svm.cv_results_['mean_test_score']
    stds = svm.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, svm.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, svm.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()

svm_model = SVC(kernel='rbf', C=100, gamma = 0.0001, random_state=42)
svm_model.fit(X_train, y_train)
spred = svm_model.predict(X_test)
print ('Accuracy with SVM {0}'.format(accuracy_score(spred, y_test) * 100))
# Out:
# # Tuning hyper-parameters for precision
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Best parameters set found on development set:
#
# {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'rbf', 'shrinking': True}
#
# Grid scores on development set:
#
# 0.751 (+/-0.081) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'linear', 'shrinking': False}
# 0.681 (+/-0.071) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'rbf', 'shrinking': True}
# 0.681 (+/-0.071) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'linear', 'shrinking': False}
# 0.725 (+/-0.195) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'rbf', 'shrinking': True}
# 0.725 (+/-0.195) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'linear', 'shrinking': False}
# 0.595 (+/-0.325) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'rbf', 'shrinking': True}
# 0.595 (+/-0.325) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': False}
# 0.740 (+/-0.051) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': True}
# 0.740 (+/-0.051) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'linear', 'shrinking': False}
# 0.681 (+/-0.071) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'rbf', 'shrinking': True}
# 0.681 (+/-0.071) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'linear', 'shrinking': False}
# 0.725 (+/-0.195) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'rbf', 'shrinking': True}
# 0.725 (+/-0.195) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'linear', 'shrinking': False}
# 0.595 (+/-0.325) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'rbf', 'shrinking': True}
# 0.595 (+/-0.325) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': False}
# 0.740 (+/-0.051) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': True}
# 0.740 (+/-0.051) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': False}
# 0.756 (+/-0.085) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'linear', 'shrinking': True}
# 0.756 (+/-0.085) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'linear', 'shrinking': False}
# 0.327 (+/-0.002) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'rbf', 'shrinking': True}
# 0.327 (+/-0.002) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'rbf', 'shrinking': False}
# 0.756 (+/-0.085) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'linear', 'shrinking': True}
# 0.756 (+/-0.085) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'linear', 'shrinking': False}
# 0.327 (+/-0.002) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'rbf', 'shrinking': True}
# 0.327 (+/-0.002) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'rbf', 'shrinking': False}
# 0.756 (+/-0.085) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'linear', 'shrinking': True}
# 0.756 (+/-0.085) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'linear', 'shrinking': False}
# 0.327 (+/-0.002) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'rbf', 'shrinking': True}
# 0.327 (+/-0.002) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'rbf', 'shrinking': False}
# 0.756 (+/-0.085) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': True}
# 0.756 (+/-0.085) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': False}
# 0.746 (+/-0.083) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': True}
# 0.746 (+/-0.083) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': False}
# 0.756 (+/-0.085) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'linear', 'shrinking': True}
# 0.756 (+/-0.085) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'linear', 'shrinking': False}
# 0.327 (+/-0.002) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'rbf', 'shrinking': True}
# 0.327 (+/-0.002) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'rbf', 'shrinking': False}
# 0.756 (+/-0.085) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'linear', 'shrinking': True}
# 0.756 (+/-0.085) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'linear', 'shrinking': False}
# 0.327 (+/-0.002) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'rbf', 'shrinking': True}
# 0.327 (+/-0.002) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'rbf', 'shrinking': False}
# 0.756 (+/-0.085) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'linear', 'shrinking': True}
# 0.756 (+/-0.085) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'linear', 'shrinking': False}
# 0.327 (+/-0.002) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'rbf', 'shrinking': True}
# 0.327 (+/-0.002) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'rbf', 'shrinking': False}
# 0.756 (+/-0.085) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': True}
# 0.756 (+/-0.085) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': False}
# 0.746 (+/-0.083) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': True}
# 0.746 (+/-0.083) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'linear', 'shrinking': False}
# 0.775 (+/-0.145) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'rbf', 'shrinking': True}
# 0.775 (+/-0.145) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'linear', 'shrinking': False}
# 0.327 (+/-0.002) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'rbf', 'shrinking': True}
# 0.327 (+/-0.002) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'linear', 'shrinking': False}
# 0.327 (+/-0.002) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'rbf', 'shrinking': True}
# 0.327 (+/-0.002) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': False}
# 0.737 (+/-0.074) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': True}
# 0.737 (+/-0.074) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'linear', 'shrinking': False}
# 0.775 (+/-0.145) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'rbf', 'shrinking': True}
# 0.775 (+/-0.145) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'linear', 'shrinking': False}
# 0.327 (+/-0.002) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'rbf', 'shrinking': True}
# 0.327 (+/-0.002) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'linear', 'shrinking': False}
# 0.327 (+/-0.002) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'rbf', 'shrinking': True}
# 0.327 (+/-0.002) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': False}
# 0.737 (+/-0.074) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': True}
# 0.737 (+/-0.074) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'linear', 'shrinking': False}
# 0.645 (+/-0.133) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'rbf', 'shrinking': True}
# 0.645 (+/-0.133) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'linear', 'shrinking': False}
# 0.680 (+/-0.405) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'rbf', 'shrinking': True}
# 0.680 (+/-0.405) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'linear', 'shrinking': False}
# 0.327 (+/-0.002) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'rbf', 'shrinking': True}
# 0.327 (+/-0.002) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': False}
# 0.749 (+/-0.072) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': True}
# 0.749 (+/-0.072) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'linear', 'shrinking': False}
# 0.645 (+/-0.133) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'rbf', 'shrinking': True}
# 0.645 (+/-0.133) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'linear', 'shrinking': False}
# 0.680 (+/-0.405) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'rbf', 'shrinking': True}
# 0.680 (+/-0.405) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'linear', 'shrinking': False}
# 0.327 (+/-0.002) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'rbf', 'shrinking': True}
# 0.327 (+/-0.002) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'rbf', 'shrinking': False}
# 0.751 (+/-0.081) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': True}
# 0.751 (+/-0.081) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': False}
# 0.749 (+/-0.072) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': True}
# 0.749 (+/-0.072) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': False}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.97      0.78       123
#            1       0.60      0.09      0.15        69
#
#     accuracy                           0.65       192
#    macro avg       0.63      0.53      0.47       192
# weighted avg       0.63      0.65      0.55       192
#
#
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'linear', 'shrinking': True}
#
# Grid scores on development set:
#
# 0.722 (+/-0.066) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'linear', 'shrinking': False}
# 0.611 (+/-0.053) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'rbf', 'shrinking': True}
# 0.611 (+/-0.053) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'linear', 'shrinking': False}
# 0.526 (+/-0.023) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'rbf', 'shrinking': True}
# 0.526 (+/-0.023) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'linear', 'shrinking': False}
# 0.509 (+/-0.013) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'rbf', 'shrinking': True}
# 0.509 (+/-0.013) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': False}
# 0.710 (+/-0.063) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': True}
# 0.710 (+/-0.063) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'linear', 'shrinking': False}
# 0.611 (+/-0.053) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'rbf', 'shrinking': True}
# 0.611 (+/-0.053) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'linear', 'shrinking': False}
# 0.526 (+/-0.023) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'rbf', 'shrinking': True}
# 0.526 (+/-0.023) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'linear', 'shrinking': False}
# 0.509 (+/-0.013) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'rbf', 'shrinking': True}
# 0.509 (+/-0.013) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': False}
# 0.710 (+/-0.063) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': True}
# 0.710 (+/-0.063) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': False}
# 0.723 (+/-0.075) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'linear', 'shrinking': True}
# 0.723 (+/-0.075) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'linear', 'shrinking': False}
# 0.500 (+/-0.000) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'rbf', 'shrinking': True}
# 0.500 (+/-0.000) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'rbf', 'shrinking': False}
# 0.723 (+/-0.075) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'linear', 'shrinking': True}
# 0.723 (+/-0.075) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'linear', 'shrinking': False}
# 0.500 (+/-0.000) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'rbf', 'shrinking': True}
# 0.500 (+/-0.000) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'rbf', 'shrinking': False}
# 0.723 (+/-0.075) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'linear', 'shrinking': True}
# 0.723 (+/-0.075) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'linear', 'shrinking': False}
# 0.500 (+/-0.000) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'rbf', 'shrinking': True}
# 0.500 (+/-0.000) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'rbf', 'shrinking': False}
# 0.723 (+/-0.075) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': True}
# 0.723 (+/-0.075) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': False}
# 0.695 (+/-0.073) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': True}
# 0.695 (+/-0.073) for {'C': 0.25, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': False}
# 0.723 (+/-0.075) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'linear', 'shrinking': True}
# 0.723 (+/-0.075) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'linear', 'shrinking': False}
# 0.500 (+/-0.000) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'rbf', 'shrinking': True}
# 0.500 (+/-0.000) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'rbf', 'shrinking': False}
# 0.723 (+/-0.075) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'linear', 'shrinking': True}
# 0.723 (+/-0.075) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'linear', 'shrinking': False}
# 0.500 (+/-0.000) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'rbf', 'shrinking': True}
# 0.500 (+/-0.000) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'rbf', 'shrinking': False}
# 0.723 (+/-0.075) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'linear', 'shrinking': True}
# 0.723 (+/-0.075) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'linear', 'shrinking': False}
# 0.500 (+/-0.000) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'rbf', 'shrinking': True}
# 0.500 (+/-0.000) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'rbf', 'shrinking': False}
# 0.723 (+/-0.075) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': True}
# 0.723 (+/-0.075) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': False}
# 0.695 (+/-0.073) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': True}
# 0.695 (+/-0.073) for {'C': 0.25, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'linear', 'shrinking': False}
# 0.525 (+/-0.008) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'rbf', 'shrinking': True}
# 0.525 (+/-0.008) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'linear', 'shrinking': False}
# 0.500 (+/-0.000) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'rbf', 'shrinking': True}
# 0.500 (+/-0.000) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'linear', 'shrinking': False}
# 0.500 (+/-0.000) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'rbf', 'shrinking': True}
# 0.500 (+/-0.000) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': False}
# 0.703 (+/-0.075) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': True}
# 0.703 (+/-0.075) for {'C': 0.5, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'linear', 'shrinking': False}
# 0.525 (+/-0.008) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'rbf', 'shrinking': True}
# 0.525 (+/-0.008) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'linear', 'shrinking': False}
# 0.500 (+/-0.000) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'rbf', 'shrinking': True}
# 0.500 (+/-0.000) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'linear', 'shrinking': False}
# 0.500 (+/-0.000) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'rbf', 'shrinking': True}
# 0.500 (+/-0.000) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': False}
# 0.703 (+/-0.075) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': True}
# 0.703 (+/-0.075) for {'C': 0.5, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'linear', 'shrinking': False}
# 0.549 (+/-0.055) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'rbf', 'shrinking': True}
# 0.549 (+/-0.055) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 1, 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'linear', 'shrinking': False}
# 0.514 (+/-0.020) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'rbf', 'shrinking': True}
# 0.514 (+/-0.020) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 2, 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'linear', 'shrinking': False}
# 0.500 (+/-0.000) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'rbf', 'shrinking': True}
# 0.500 (+/-0.000) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 3, 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': False}
# 0.717 (+/-0.071) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': True}
# 0.717 (+/-0.071) for {'C': 0.75, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'linear', 'shrinking': False}
# 0.549 (+/-0.055) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'rbf', 'shrinking': True}
# 0.549 (+/-0.055) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 1, 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'linear', 'shrinking': False}
# 0.514 (+/-0.020) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'rbf', 'shrinking': True}
# 0.514 (+/-0.020) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 2, 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'linear', 'shrinking': False}
# 0.500 (+/-0.000) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'rbf', 'shrinking': True}
# 0.500 (+/-0.000) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 3, 'kernel': 'rbf', 'shrinking': False}
# 0.722 (+/-0.066) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': True}
# 0.722 (+/-0.066) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'linear', 'shrinking': False}
# 0.717 (+/-0.071) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': True}
# 0.717 (+/-0.071) for {'C': 0.75, 'decision_function_shape': 'ovr', 'gamma': 'auto', 'kernel': 'rbf', 'shrinking': False}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.79       123
#            1       0.63      0.64      0.63        69
#
#     accuracy                           0.73       192
#    macro avg       0.71      0.71      0.71       192
# weighted avg       0.74      0.73      0.73       192
#
#
# Accuracy with SVM 73.95833333333334

# %%
# Making the Confusion Matrix
from sklearn.metrics import classification_report, confusion_matrix
cm = confusion_matrix(y_test, y_pred)

print('TP - True Negative {}'.format(cm[0,0]))
print('FP - False Positive {}'.format(cm[0,1]))
print('FN - False Negative {}'.format(cm[1,0]))
print('TP - True Positive {}'.format(cm[1,1]))
print('Accuracy Rate: {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]),np.sum(cm))))
print('Misclassification Rate: {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))))

round(roc_auc_score(y_test,y_pred),5)
# Out:
# TP - True Negative 97
# FP - False Positive 26
# FN - False Negative 25
# TP - True Positive 44
# Accuracy Rate: 0.734375
# Misclassification Rate: 0.265625
# 0.71315
